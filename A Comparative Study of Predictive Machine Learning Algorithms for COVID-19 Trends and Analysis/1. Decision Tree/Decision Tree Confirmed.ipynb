# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df = pd.read_csv('India_Confirmed_Cases_21.csv',index_col = 'Date')
df.head()
# Out:
#          Confirm
# Date
# 1/1/21  10325823
# 1/2/21  10323965
# 1/3/21  10340469
# 1/4/21  10356844
# 1/5/21  10374932

# %%
Confirmed_Deaths = pd.read_csv('India_Confirmed_Deaths_21.csv',index_col = 'Date')
Confirmed_Deaths.head()
# Out:
#         Confirm Death
# Date
# 1/1/21         149474
# 1/2/21         149435
# 1/3/21         149649
# 1/4/21         149850
# 1/5/21         150114

# %%
Recovered_Cases = pd.read_csv('India_Recovered_Cases_21.csv', index_col = 'Date')
Recovered_Cases.head()
# Out:
#         Recovered_Cases
# Date
# 1/1/21          9929568
# 1/2/21          9927310
# 1/3/21          9946867
# 1/4/21          9975958
# 1/5/21          9997272

# %% [markdown]
# ## Confirmed_Covid-19_Cases_India_2021

# %%
plt.figure(figsize=(30,8))
plt.title('Confirmed Cases in India 2021')
plt.xlabel('Dates')
plt.ylabel('Confirmed Cases')
plt.plot(df['Confirm'])
plt.show()

# %%
future_days = 25
df['Predicted Cases'] = df['Confirm'].shift(-future_days)
df.head()
# Out:
#          Confirm  Predicted Cases
# Date
# 1/1/21  10325823       10689527.0
# 1/2/21  10323965       10701193.0
# 1/3/21  10340469       10720048.0
# 1/4/21  10356844       10733130.0
# 1/5/21  10374932       10746174.0

# %%
df.tail(25)
# Out:
#           Confirm  Predicted Cases
# Date
# 9/2/21   32903289              NaN
# 9/3/21   32945907              NaN
# 9/4/21   32988673              NaN
# 9/5/21   33027621              NaN
# 9/6/21   33058843              NaN
# 9/7/21   33096718              NaN
# 9/8/21   33139981              NaN
# 9/9/21   33174954              NaN
# 9/10/21  33208330              NaN
# 9/11/21  33236921              NaN
# 9/12/21  33264175              NaN
# 9/13/21  33289579              NaN
# 9/14/21  33316755              NaN
# 9/15/21  33347325              NaN
# 9/16/21  33381728              NaN
# 9/17/21  33417390              NaN
# 9/18/21  33448163              NaN
# 9/19/21  33478419              NaN
# 9/20/21  33504534              NaN
# 9/21/21  33531498              NaN
# 9/22/21  33563421              NaN
# 9/23/21  33594803              NaN
# 9/24/21  33624419              NaN
# 9/25/21  33652745              NaN
# 9/26/21  33678786              NaN

# %%
X = np.array(df.drop(['Predicted Cases'], 1))[:-future_days]
print(X)
# Out:
# [[10325823]
#  [10323965]
#  [10340469]
#  [10356844]
#  [10374932]
#  [10395278]
#  [10413417]
#  [10413417]
#  [10450284]
#  [10466595]
#  [10479179]
#  [10495147]
#  [10512093]
#  [10527683]
#  [10542841]
#  [10557985]
#  [10571773]
#  [10581823]
#  [10595639]
#  [10610883]
#  [10625428]
#  [10639684]
#  [10654533]
#  [10667736]
#  [10676838]
#  [10689527]
#  [10701193]
#  [10720048]
#  [10733130]
#  [10746174]
#  [10757610]
#  [10766245]
#  [10777284]
#  [10790183]
#  [10802591]
#  [10814304]
#  [10826363]
#  [10838194]
#  [10847304]
#  [10858371]
#  [10871294]
#  [10880603]
#  [10892746]
#  [10904940]
#  [10916589]
#  [10925710]
#  [10937320]
#  [10950201]
#  [10963394]
#  [10977387]
#  [10991651]
#  [11005850]
#  [11016434]
#  [11030176]
#  [11046914]
#  [11063491]
#  [11079979]
#  [11096731]
#  [11112241]
#  [11124527]
#  [11139516]
#  [11156923]
#  [11173761]
#  [11192045]
#  [11210799]
#  [11229398]
#  [11244786]
#  [11262707]
#  [11285561]
#  [11308846]
#  [11333728]
# ...

# %%
y = np.array(df['Predicted Cases'])[:-future_days]
print(y)
# Out:
# [10689527. 10701193. 10720048. 10733130. 10746174. 10757610. 10766245.
#  10777284. 10790183. 10802591. 10814304. 10826363. 10838194. 10847304.
#  10858371. 10871294. 10880603. 10892746. 10904940. 10916589. 10925710.
#  10937320. 10950201. 10963394. 10977387. 10991651. 11005850. 11016434.
#  11030176. 11046914. 11063491. 11079979. 11096731. 11112241. 11124527.
#  11139516. 11156923. 11173761. 11192045. 11210799. 11229398. 11244786.
#  11262707. 11285561. 11308846. 11333728. 11359048. 11385339. 11409831.
#  11438734. 11474605. 11514331. 11555284. 11599130. 11646081. 11686796.
#  11734058. 11787534. 11846652. 11908910. 11971624. 12039644. 12095855.
#  12149335. 12221665. 12303131. 12392260. 12485509. 12589067. 12686049.
#  12801785. 12928574. 13060542. 13205926. 13358805. 13527717. 13689453.
#  13873825. 14074564. 14291917. 14526609. 14788003. 15061805. 15320972.
#  15616130. 15930774. 16263695. 16610481. 16960172. 17313163. 17636186.
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
tree = DecisionTreeRegressor().fit(x_train, y_train)
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = df.drop(['Predicted Cases'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# /var/folders/n7/3q5192g500dbk8ndkh5r6l8r0000gn/T/ipykernel_44089/3835655274.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x_future = df.drop(['Predicted Cases'], 1)[:-future_days]
# array([[31969954],
#        [31998158],
#        [32036511],
#        [32077706],
#        [32117826],
#        [32156493],
#        [32192576],
#        [32225513],
#        [32250679],
#        [32285857],
#        [32322258],
#        [32358829],
#        [32393286],
#        [32424234],
#        [32449306],
#        [32474773],
#        [32512366],
#        [32558530],
#        [32603188],
#        [32649947],
#        [32695030],
#        [32737939],
#        [32768880],
#        [32810845],
#        [32857937]])

# %%
tree_predictions = tree.predict(x_future)
print(tree_predictions)
print()
lr_predictions = lr.predict(x_future)
print(lr_predictions)
# Out:
# [32903289. 32945907. 32945907. 33058843. 33058843. 33096718. 33139981.
#  33174954. 33208330. 33236921. 33264175. 33289579. 33316755. 33347325.
#  33381728. 33381728. 33448163. 33478419. 33504534. 33531498. 33563421.
#  33624419. 33624419. 33624419. 33678786.]
#
# [33752738.21456477 33779656.38016801 33816260.84781022 33855577.74725801
#  33893868.6564908  33930772.80871674 33965210.76678871 33996646.15256639
#  34020664.82210161 34054239.03957397 34088980.49986767 34123884.20977676
#  34156770.29799797 34186307.36327554 34210236.31831754 34234542.26511294
#  34270421.3815334  34314480.74179818 34357102.76135248 34401729.99527113
#  34444757.63886391 34485710.39619866 34515240.78060973 34555292.57537431
#  34600237.62765723]

# %%
predictions = tree_predictions

valid = Confirmed_Cases[X.shape[0]:]
valid['Predicted Cases'] = predictions

plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Dates')
plt.ylabel('Predicted Cases')
plt.plot(Confirmed_Cases['Confirmed Cases'])
plt.plot(valid['Confirmed Cases'])
plt.plot(valid['Predicted Cases'])
plt.legend(['Orig', 'Val', 'Pred'])
plt.show()
# Out:
# /var/folders/n7/3q5192g500dbk8ndkh5r6l8r0000gn/T/ipykernel_44089/2099714479.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predicted Cases'] = predictions

# %%
valid
# Out:
#          Confirmed Cases  Predicted Cases
# Date
# 9/2/21          32903289       32903289.0
# 9/3/21          32945907       32945907.0
# 9/4/21          32988673       32945907.0
# 9/5/21          33027621       33058843.0
# 9/6/21          33058843       33058843.0
# 9/7/21          33096718       33096718.0
# 9/8/21          33139981       33139981.0
# 9/9/21          33174954       33174954.0
# 9/10/21         33208330       33208330.0
# 9/11/21         33236921       33236921.0
# 9/12/21         33264175       33264175.0
# 9/13/21         33289579       33289579.0
# 9/14/21         33316755       33316755.0
# 9/15/21         33347325       33347325.0
# 9/16/21         33381728       33381728.0
# 9/17/21         33417390       33381728.0
# 9/18/21         33448163       33448163.0
# 9/19/21         33478419       33478419.0
# 9/20/21         33504534       33504534.0
# 9/21/21         33531498       33531498.0
# 9/22/21         33563421       33563421.0
# ...

# %%
from sklearn.metrics import r2_score
score = r2_score(valid['Confirmed Cases'], valid['Predicted Cases'])
print(score)
# Out:
# 0.9955880009085849

# %%
valid.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
